# %%
#Importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
airline=pd.read_csv(r"C:\Users\Sourabh\Downloads\archive (26)\train.csv")

# %%
airline
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival Delay in Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %% [markdown]
# ##### checking the weightage of sub types in category variables

# %%
airline['Customer Type'].value_counts()
# Out:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64

# %%
airline['Type of Travel'].value_counts()
# Out:
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64

# %%
airline['Class'].value_counts()
# Out:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %%
airline.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# #### dropping unwanted columns

# %%
airline.drop(columns=['Unnamed: 0', 'id'],axis=1,inplace=True)

# %%
airline['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
airline['satisfaction'].replace({'neutral or dissatisfied':'dissatisfied'},inplace=True)

# %%
airline
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate location  ...  Inflight entertainment  On-board service  \
# 0                   1  ...                       5                 4
# 1                   3  ...                       1                 1
# 2                   2  ...                       5                 4
# 3                   5  ...                       2                 2
# 4                   3  ...                       3                 3
# ...               ...  ...                     ...               ...
# 103899              3  ...                       2                 3
# 103900              4  ...                       5                 5
# 103901              3  ...                       4                 3
# 103902              5  ...                       1                 4
# 103903              3  ...                       1                 1
#
#         Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                      3                 4                4                 5
# 1                      5                 3                1                 4
# 2                      3                 4                4                 4
# 3                      5                 3                1                 4
# 4                      4                 4                3                 3
# ...                  ...               ...              ...               ...
# 103899                 1                 4                2                 3
# 103900                 5                 5                5                 5
# 103901                 2                 4                5                 5
# 103902                 5                 1                5                 4
# 103903                 1                 4                4                 3
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                 5                          25                      18.0
# 1                 1                           1                       6.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# ...             ...                         ...                       ...
# 103899            2                           3                       0.0
# 103900            4                           0                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
# 103903            1                           0                       0.0
#
#         satisfaction
# 0       dissatisfied
# 1       dissatisfied
# 2          satisfied
# 3       dissatisfied
# 4          satisfied
# ...              ...
# 103899  dissatisfied
# 103900     satisfied
# 103901  dissatisfied
# 103902  dissatisfied
# 103903  dissatisfied
#
# [103904 rows x 23 columns]

# %%
airline
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate location  ...  Inflight entertainment  On-board service  \
# 0                   1  ...                       5                 4
# 1                   3  ...                       1                 1
# 2                   2  ...                       5                 4
# 3                   5  ...                       2                 2
# 4                   3  ...                       3                 3
# ...               ...  ...                     ...               ...
# 103899              3  ...                       2                 3
# 103900              4  ...                       5                 5
# 103901              3  ...                       4                 3
# 103902              5  ...                       1                 4
# 103903              3  ...                       1                 1
#
#         Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                      3                 4                4                 5
# 1                      5                 3                1                 4
# 2                      3                 4                4                 4
# 3                      5                 3                1                 4
# 4                      4                 4                3                 3
# ...                  ...               ...              ...               ...
# 103899                 1                 4                2                 3
# 103900                 5                 5                5                 5
# 103901                 2                 4                5                 5
# 103902                 5                 1                5                 4
# 103903                 1                 4                4                 3
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                 5                          25                      18.0
# 1                 1                           1                       6.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# ...             ...                         ...                       ...
# 103899            2                           3                       0.0
# 103900            4                           0                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
# 103903            1                           0                       0.0
#
#         satisfaction
# 0       dissatisfied
# 1       dissatisfied
# 2          satisfied
# 3       dissatisfied
# 4          satisfied
# ...              ...
# 103899  dissatisfied
# 103900     satisfied
# 103901  dissatisfied
# 103902  dissatisfied
# 103903  dissatisfied
#
# [103904 rows x 23 columns]

# %%
pd.set_option('display.max_columns',25)

# %%
airline['Seat comfort'].value_counts()
# Out:
# 4    31765
# 5    26470
# 3    18696
# 2    14897
# 1    12075
# 0        1
# Name: Seat comfort, dtype: int64

# %% [markdown]
# #### visual representation of categorical data

# %%
import matplotlib.pyplot as plt 
for column in airline.select_dtypes(include='object'):
    plt.figure(figsize=(12, 5))  
    sns.countplot(x=column, data=airline)

# %%
for i in ['Gender', 'Customer Type','Type of Travel','Class']:
    print(airline[i].value_counts())
# Out:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
#  11  Online boarding                    103904 non-null  int64
#  12  Seat comfort                       103904 non-null  int64
#  13  Inflight entertainment             103904 non-null  int64
#  14  On-board service                   103904 non-null  int64
#  15  Leg room service                   103904 non-null  int64
#  16  Baggage handling                   103904 non-null  int64
#  17  Checkin service                    103904 non-null  int64
#  18  Inflight service                   103904 non-null  int64
#  19  Cleanliness                        103904 non-null  int64
#  20  Departure Delay in Minutes         103904 non-null  int64
#  21  Arrival Delay in Minutes           103594 non-null  float64
#  22  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 18.2+ MB

# %% [markdown]
# #### checking nan's

# %%
airline.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %% [markdown]
# #### handling outliers

# %%
sns.boxplot(data=airline['Arrival Delay in Minutes'])
# Out:
# <Axes: >

# %% [markdown]
# #### filling out nan values

# %%
airline['Arrival Delay in Minutes'].fillna(airline['Arrival Delay in Minutes'].median(),inplace = True)

# %%
airline.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
for i in ['Age','Flight Distance','Departure Delay in Minutes','Arrival Delay in Minutes']:                  
    if airline[i].dtypes in ("float64","int64"):
        q1 = airline[i].quantile(0.25) 
        q3 = airline[i].quantile(0.75)  
        iqr = q3-q1 
        ul = q3 + 1.5*iqr       
        ll = q1 - 1.5*iqr 
        airline[i].clip(upper=ul,lower=ll,inplace=True)

# %%
airline
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                 460.0                      3
# 1                 235.0                      3
# 2                1142.0                      2
# 3                 562.0                      2
# 4                 214.0                      3
# ...                 ...                    ...
# 103899            192.0                      2
# 103900           2347.0                      4
# 103901           1995.0                      1
# 103902           1000.0                      1
# 103903           1723.0                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate location  Food and drink  Online boarding  Seat comfort  \
# 0                   1               5                3             5
# 1                   3               1                3             1
# 2                   2               5                5             5
# 3                   5               2                2             2
# 4                   3               4                5             5
# ...               ...             ...              ...           ...
# 103899              3               2                2             2
# 103900              4               2                4             5
# 103901              3               4                1             5
# 103902              5               1                1             1
# 103903              3               1                1             1
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 4                            3                 3                 4
# ...                        ...               ...               ...
# 103899                       2                 3                 1
# 103900                       5                 5                 5
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 0                               25                      18.0  dissatisfied
# 1                                1                       6.0  dissatisfied
# 2                                0                       0.0     satisfied
# 3                               11                       9.0  dissatisfied
# 4                                0                       0.0     satisfied
# ...                            ...                       ...           ...
# 103899                           3                       0.0  dissatisfied
# 103900                           0                       0.0     satisfied
# 103901                           7                      14.0  dissatisfied
# 103902                           0                       0.0  dissatisfied
# 103903                           0                       0.0  dissatisfied
#
# [103904 rows x 23 columns]

# %% [markdown]
# ### analysis for finding factors affecting dissatisfied customers

# %%
disstisfied= airline[airline["satisfaction"] == "dissatisfied"]  

disstisfied
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 5       Female     Loyal Customer   26  Personal Travel       Eco
# 6         Male     Loyal Customer   47  Personal Travel       Eco
# ...        ...                ...  ...              ...       ...
# 103898    Male     Loyal Customer   50  Personal Travel       Eco
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                 460.0                      3
# 1                 235.0                      3
# 3                 562.0                      2
# 5                1180.0                      3
# 6                1276.0                      2
# ...                 ...                    ...
# 103898           1620.0                      3
# 103899            192.0                      2
# 103901           1995.0                      1
# 103902           1000.0                      1
# 103903           1723.0                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 3                                       5                       5
# 5                                       4                       2
# 6                                       4                       2
# ...                                   ...                     ...
# 103898                                  1                       3
# 103899                                  1                       2
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate location  Food and drink  Online boarding  Seat comfort  \
# 0                   1               5                3             5
# 1                   3               1                3             1
# 3                   5               2                2             2
# 5                   1               1                2             1
# 6                   3               2                2             2
# ...               ...             ...              ...           ...
# 103898              4               2                3             2
# 103899              3               2                2             2
# 103901              3               4                1             5
# 103902              5               1                1             1
# 103903              3               1                1             1
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 3                            2                 2                 5
# 5                            1                 3                 4
# 6                            2                 3                 3
# ...                        ...               ...               ...
# 103898                       2                 4                 3
# 103899                       2                 3                 1
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 3                      3                1                 4            2
# 5                      4                4                 4            1
# 6                      4                3                 5            2
# ...                  ...              ...               ...          ...
# 103898                 4                2                 4            2
# 103899                 4                2                 3            2
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 0                               25                      18.0  dissatisfied
# 1                                1                       6.0  dissatisfied
# 3                               11                       9.0  dissatisfied
# 5                                0                       0.0  dissatisfied
# 6                                9                      23.0  dissatisfied
# ...                            ...                       ...           ...
# 103898                           0                       0.0  dissatisfied
# 103899                           3                       0.0  dissatisfied
# 103901                           7                      14.0  dissatisfied
# 103902                           0                       0.0  dissatisfied
# 103903                           0                       0.0  dissatisfied
#
# [58879 rows x 23 columns]

# %%
disstisfied.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
list1=[]
for i in ['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']:
    list1.append((i,disstisfied[i].mean()))

# %%
list1
# Out:
# [('Inflight wifi service', 2.3996331459433753),
#  ('Departure/Arrival time convenient', 3.1291122471509367),
#  ('Ease of Online booking', 2.5468503201481005),
#  ('Gate location', 2.9761205183511947),
#  ('Food and drink', 2.9580495592656124),
#  ('Online boarding', 2.656125273866744),
#  ('Seat comfort', 3.0362947740280917),
#  ('Inflight entertainment', 2.894155811070161),
#  ('On-board service', 3.019157934068174),
#  ('Leg room service', 2.990811664600282),
#  ('Baggage handling', 3.375991440072012),
#  ('Checkin service', 3.042952495796464),
#  ('Inflight service', 3.3888143480697703),
#  ('Cleanliness', 2.936123235788651)]

# %%
list2=list(filter(lambda x:x[1]<3,list1))

# %%
list2
# Out:
# [('Inflight wifi service', 2.3996331459433753),
#  ('Ease of Online booking', 2.5468503201481005),
#  ('Gate location', 2.9761205183511947),
#  ('Food and drink', 2.9580495592656124),
#  ('Online boarding', 2.656125273866744),
#  ('Inflight entertainment', 2.894155811070161),
#  ('Leg room service', 2.990811664600282),
#  ('Cleanliness', 2.936123235788651)]

# %%
filt=disstisfied['Customer Type']=='Loyal Customer'
loyal_d=disstisfied[filt]

# %%
loyal_d
# Out:
#         Gender   Customer Type  Age   Type of Travel     Class  \
# 0         Male  Loyal Customer   13  Personal Travel  Eco Plus
# 3       Female  Loyal Customer   25  Business travel  Business
# 5       Female  Loyal Customer   26  Personal Travel       Eco
# 6         Male  Loyal Customer   47  Personal Travel       Eco
# 8       Female  Loyal Customer   41  Business travel  Business
# ...        ...             ...  ...              ...       ...
# 103884  Female  Loyal Customer   19  Personal Travel       Eco
# 103893  Female  Loyal Customer   58  Business travel  Business
# 103896    Male  Loyal Customer   57  Business travel       Eco
# 103898    Male  Loyal Customer   50  Personal Travel       Eco
# 103903    Male  Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                 460.0                      3
# 3                 562.0                      2
# 5                1180.0                      3
# 6                1276.0                      2
# 8                 853.0                      1
# ...                 ...                    ...
# 103884            334.0                      2
# 103893            296.0                      3
# 103896            867.0                      4
# 103898           1620.0                      3
# 103903           1723.0                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 3                                       5                       5
# 5                                       4                       2
# 6                                       4                       2
# 8                                       2                       2
# ...                                   ...                     ...
# 103884                                  5                       2
# 103893                                  3                       5
# 103896                                  5                       5
# 103898                                  1                       3
# 103903                                  3                       3
#
#         Gate location  Food and drink  Online boarding  Seat comfort  \
# 0                   1               5                3             5
# 3                   5               2                2             2
# 5                   1               1                2             1
# 6                   3               2                2             2
# 8                   2               4                3             3
# ...               ...             ...              ...           ...
# 103884              1               5                2             5
# 103893              3               2                3             4
# 103896              5               4                4             4
# 103898              4               2                3             2
# 103903              3               1                1             1
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 3                            2                 2                 5
# 5                            1                 3                 4
# 6                            2                 3                 3
# 8                            1                 1                 2
# ...                        ...               ...               ...
# 103884                       5                 3                 2
# 103893                       3                 3                 3
# 103896                       4                 3                 4
# 103898                       2                 4                 3
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 3                      3                1                 4            2
# 5                      4                4                 4            1
# 6                      4                3                 5            2
# 8                      1                4                 1            2
# ...                  ...              ...               ...          ...
# 103884                 4                3                 5            5
# 103893                 3                1                 3            1
# 103896                 3                1                 3            4
# 103898                 4                2                 4            2
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 0                               25                      18.0  dissatisfied
# 3                               11                       9.0  dissatisfied
# 5                                0                       0.0  dissatisfied
# 6                                9                      23.0  dissatisfied
# 8                                0                       0.0  dissatisfied
# ...                            ...                       ...           ...
# 103884                          25                      11.0  dissatisfied
# 103893                           0                      29.0  dissatisfied
# 103896                           0                       0.0  dissatisfied
# 103898                           0                       0.0  dissatisfied
# 103903                           0                       0.0  dissatisfied
#
# [44390 rows x 23 columns]

# %%
list_loyal=[]
for i in ['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']:
    list_loyal.append((i,loyal_d[i].mean()))

# %%
list_loyal
# Out:
# [('Inflight wifi service', 2.4013967109709395),
#  ('Departure/Arrival time convenient', 3.403942329353458),
#  ('Ease of Online booking', 2.5967109709394007),
#  ('Gate location', 2.953345348051363),
#  ('Food and drink', 2.940662311331381),
#  ('Online boarding', 2.7314259968461365),
#  ('Seat comfort', 3.0528722685289478),
#  ('Inflight entertainment', 2.8496282946609597),
#  ('On-board service', 2.9999324172110837),
#  ('Leg room service', 2.9335661184951567),
#  ('Baggage handling', 3.314395134039198),
#  ('Checkin service', 3.0377337238116695),
#  ('Inflight service', 3.329736427123226),
#  ('Cleanliness', 2.9007434106780807)]

# %%
list_loyal_filtered=list(filter(lambda x:x[1]<3,list_loyal))

# %% [markdown]
# ### step1

# %%
list_loyal_filtered
# Out:
# [('Inflight wifi service', 2.4013967109709395),
#  ('Ease of Online booking', 2.5967109709394007),
#  ('Gate location', 2.953345348051363),
#  ('Food and drink', 2.940662311331381),
#  ('Online boarding', 2.7314259968461365),
#  ('Inflight entertainment', 2.8496282946609597),
#  ('On-board service', 2.9999324172110837),
#  ('Leg room service', 2.9335661184951567),
#  ('Cleanliness', 2.9007434106780807)]

# %%
filt1=disstisfied['Customer Type']=='disloyal Customer'
disloyal_d=disstisfied[filt1]

# %%
disloyal_d
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 1         Male  disloyal Customer   25  Business travel  Business
# 9         Male  disloyal Customer   20  Business travel       Eco
# 10      Female  disloyal Customer   24  Business travel       Eco
# 15        Male  disloyal Customer   13  Business travel       Eco
# 31      Female  disloyal Customer   15  Business travel       Eco
# ...        ...                ...  ...              ...       ...
# 103892  Female  disloyal Customer   37  Business travel  Business
# 103895  Female  disloyal Customer   24  Business travel       Eco
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 1                 235.0                      3
# 9                1061.0                      3
# 10               1182.0                      4
# 15                486.0                      2
# 31               1043.0                      2
# ...                 ...                    ...
# 103892            596.0                      3
# 103895           1055.0                      1
# 103899            192.0                      2
# 103901           1995.0                      1
# 103902           1000.0                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 1                                       2                       3
# 9                                       3                       3
# 10                                      5                       5
# 15                                      1                       2
# 31                                      2                       2
# ...                                   ...                     ...
# 103892                                  3                       3
# 103895                                  1                       1
# 103899                                  1                       2
# 103901                                  1                       1
# 103902                                  1                       1
#
#         Gate location  Food and drink  Online boarding  Seat comfort  \
# 1                   3               1                3             1
# 9                   4               2                3             3
# 10                  4               2                5             2
# 15                  3               4                2             1
# 31                  3               5                2             5
# ...               ...             ...              ...           ...
# 103892              4               3                3             3
# 103895              2               1                1             1
# 103899              3               2                2             2
# 103901              3               4                1             5
# 103902              5               1                1             1
#
#         Inflight entertainment  On-board service  Leg room service  \
# 1                            1                 1                 5
# 9                            2                 2                 3
# 10                           2                 3                 3
# 15                           4                 2                 1
# 31                           5                 3                 1
# ...                        ...               ...               ...
# 103892                       3                 1                 1
# 103895                       1                 3                 3
# 103899                       2                 3                 1
# 103901                       4                 3                 2
# 103902                       1                 4                 5
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 1                      3                1                 4            1
# 9                      4                4                 3            2
# 10                     5                3                 5            2
# 15                     4                1                 3            4
# 31                     4                2                 4            5
# ...                  ...              ...               ...          ...
# 103892                 3                1                 4            3
# 103895                 5                5                 4            1
# 103899                 4                2                 3            2
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 1                                1                       6.0  dissatisfied
# 9                                0                       0.0  dissatisfied
# 10                               0                       0.0  dissatisfied
# 15                               1                       0.0  dissatisfied
# 31                               3                       0.0  dissatisfied
# ...                            ...                       ...           ...
# 103892                          30                      32.5  dissatisfied
# 103895                          13                      10.0  dissatisfied
# 103899                           3                       0.0  dissatisfied
# 103901                           7                      14.0  dissatisfied
# 103902                           0                       0.0  dissatisfied
#
# [14489 rows x 23 columns]

# %%
list_disloyal=[]
for i in ['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']:
    list_disloyal.append((i,disloyal_d[i].mean()))

# %%
list_disloyal
# Out:
# [('Inflight wifi service', 2.39423010559735),
#  ('Departure/Arrival time convenient', 2.2871143626199184),
#  ('Ease of Online booking', 2.3940920698460904),
#  ('Gate location', 3.045896887293809),
#  ('Food and drink', 3.0113189316032853),
#  ('Online boarding', 2.425426185382014),
#  ('Seat comfort', 2.9855062461177444),
#  ('Inflight entertainment', 3.030574918903996),
#  ('On-board service', 3.0780592173372905),
#  ('Leg room service', 3.1661950445165297),
#  ('Baggage handling', 3.5647042584029265),
#  ('Checkin service', 3.058941265787839),
#  ('Inflight service', 3.569811581199531),
#  ('Cleanliness', 3.0445165297812133)]

# %%
list_disloyal_filtered=list(filter(lambda x:x[1]<3,list_disloyal))

# %% [markdown]
# ### step2

# %%
list_disloyal_filtered
# Out:
# [('Inflight wifi service', 2.39423010559735),
#  ('Departure/Arrival time convenient', 2.2871143626199184),
#  ('Ease of Online booking', 2.3940920698460904),
#  ('Online boarding', 2.425426185382014),
#  ('Seat comfort', 2.9855062461177444)]

# %%
list_loyal_filtered
# Out:
# [('Inflight wifi service', 2.4013967109709395),
#  ('Ease of Online booking', 2.5967109709394007),
#  ('Gate location', 2.953345348051363),
#  ('Food and drink', 2.940662311331381),
#  ('Online boarding', 2.7314259968461365),
#  ('Inflight entertainment', 2.8496282946609597),
#  ('On-board service', 2.9999324172110837),
#  ('Leg room service', 2.9335661184951567),
#  ('Cleanliness', 2.9007434106780807)]

# %% [markdown]
# ### common factors from loyal and disloyal

# %%
list_disloyal_filtered1=[x[0] for x in list_disloyal_filtered]
list_loyal_filtered1=[x[0] for x in list_loyal_filtered]

# %%
list_disloyal_filtered1
# Out:
# ['Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Online boarding',
#  'Seat comfort']

# %%
list_loyal_filtered1
# Out:
# ['Inflight wifi service',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Cleanliness']

# %%
common=list(filter(lambda x:x in list_disloyal_filtered1,list_loyal_filtered1))

# %% [markdown]
# # common factors

# %%
common
# Out:
# ['Inflight wifi service', 'Ease of Online booking', 'Online boarding']

# %% [markdown]
# ### ^these were factors that were mostly affecting the dissatifaction of passengers

# %% [markdown]
# ### encoding target variable

# %%
airline['satisfaction']=airline['satisfaction'].map({'dissatisfied':1,'satisfied':0})

# %%
airline
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                 460.0                      3
# 1                 235.0                      3
# 2                1142.0                      2
# 3                 562.0                      2
# 4                 214.0                      3
# ...                 ...                    ...
# 103899            192.0                      2
# 103900           2347.0                      4
# 103901           1995.0                      1
# 103902           1000.0                      1
# 103903           1723.0                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate location  Food and drink  Online boarding  Seat comfort  \
# 0                   1               5                3             5
# 1                   3               1                3             1
# 2                   2               5                5             5
# 3                   5               2                2             2
# 4                   3               4                5             5
# ...               ...             ...              ...           ...
# 103899              3               2                2             2
# 103900              4               2                4             5
# 103901              3               4                1             5
# 103902              5               1                1             1
# 103903              3               1                1             1
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 4                            3                 3                 4
# ...                        ...               ...               ...
# 103899                       2                 3                 1
# 103900                       5                 5                 5
# 103901                       4                 3                 2
# 103902                       1                 4                 5
# 103903                       1                 1                 1
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 103899                 4                2                 3            2
# 103900                 5                5                 5            4
# 103901                 4                5                 5            4
# 103902                 1                5                 4            1
# 103903                 4                4                 3            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 0                               25                      18.0             1
# 1                                1                       6.0             1
# 2                                0                       0.0             0
# 3                               11                       9.0             1
# 4                                0                       0.0             0
# ...                            ...                       ...           ...
# 103899                           3                       0.0             1
# 103900                           0                       0.0             0
# 103901                           7                      14.0             1
# 103902                           0                       0.0             1
# 103903                           0                       0.0             1
#
# [103904 rows x 23 columns]

# %%
airline.satisfaction.value_counts()
# Out:
# 1    58879
# 0    45025
# Name: satisfaction, dtype: int64

# %% [markdown]
# ### category and numbers

# %%
# Qualitative Variable
Quantitative_Variable = airline[airline.select_dtypes(include=[np.number]).columns.tolist()]
Quantitative_Variable.head(3)
# Out:
#    Age  Flight Distance  Inflight wifi service  \
# 0   13            460.0                      3
# 1   25            235.0                      3
# 2   26           1142.0                      2
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# 1                                  2                       3              3
# 2                                  2                       2              2
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# 0               5                3             5                       5
# 1               1                3             1                       1
# 2               5                5             5                       5
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             1
# 1                       6.0             1
# 2                       0.0             0

# %%
Qualitative_Variable = airline[airline.select_dtypes(include=['object']).columns.tolist()]
Qualitative_Variable.head(3)
# Out:
#    Gender      Customer Type   Type of Travel     Class
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business

# %%
#applying label encoder

# %%
from sklearn.preprocessing import LabelEncoder
Qualitative_Variable=Qualitative_Variable.apply(LabelEncoder().fit_transform) # label in ascending order
Qualitative_Variable.head()
# Out:
#    Gender  Customer Type  Type of Travel  Class
# 0       1              0               1      2
# 1       1              1               0      0
# 2       0              0               0      0
# 3       0              0               0      0
# 4       1              0               0      0

# %%
Final_combined = pd.concat([Qualitative_Variable, Quantitative_Variable],axis=1)
Final_combined.head()
# Out:
#    Gender  Customer Type  Type of Travel  Class  Age  Flight Distance  \
# 0       1              0               1      2   13            460.0
# 1       1              1               0      0   25            235.0
# 2       0              0               0      0   26           1142.0
# 3       0              0               0      0   25            562.0
# 4       1              0               0      0   61            214.0
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# 1             1                       1                 1                 5
# 2             5                       5                 4                 3
# 3             2                       2                 2                 5
# 4             5                       3                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 0                          25                      18.0             1
# 1                           1                       6.0             1
# 2                           0                       0.0             0
# 3                          11                       9.0             1
# 4                           0                       0.0             0

# %%
Final_combined.satisfaction.value_counts()
# Out:
# 1    58879
# 0    45025
# Name: satisfaction, dtype: int64

# %% [markdown]
# ### data partition

# %%
from sklearn.model_selection import train_test_split

# define our input variable (X) & output variable
X = Final_combined.drop('satisfaction', axis = 1)
Y = Final_combined[['satisfaction']]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=56)

# %%
train = pd.concat([X_train,y_train],axis=1)
train.head()
# Out:
#        Gender  Customer Type  Type of Travel  Class  Age  Flight Distance  \
# 27515       0              0               0      0   59           1726.0
# 22056       0              0               0      0   26            571.0
# 53332       1              1               0      1   20            972.0
# 47247       1              0               1      1   32            563.0
# 88195       1              0               0      0   40           1536.0
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# 27515                      5                                  1
# 22056                      1                                  1
# 53332                      2                                  2
# 47247                      3                                  4
# 88195                      5                                  5
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 27515                       5              5               5                4
# 22056                       1              1               5                5
# 53332                       2              4               4                2
# 47247                       2              1               5                2
# 88195                       5              5               2                5
#
#        Seat comfort  Inflight entertainment  On-board service  \
# 27515             4                       4                 4
# 22056             5                       5                 2
# 53332             4                       4                 4
# 47247             5                       5                 5
# 88195             4                       5                 5
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# 27515                 5                 4                3                 4
# 22056                 4                 4                5                 1
# 53332                 5                 4                3                 4
# 47247                 2                 5                4                 5
# 88195                 5                 5                5                 5
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 27515            4                           9                       0.0
# 22056            5                          30                      32.5
# 53332            4                           0                       0.0
# 47247            5                           9                      14.0
# 88195            5                          30                      32.5
#
#        satisfaction
# 27515             0
# 22056             0
# 53332             1
# 47247             1
# 88195             0

# %% [markdown]
# ### finding out important features

# %%
from sklearn.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
Model3 = sfs(logreg, n_features_to_select=10, direction='forward', scoring='accuracy',cv=5)
Model3.fit(X_train,y_train)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(),
#                           n_features_to_select=10, scoring='accuracy')

# %%
Model3.get_feature_names_out()
# Out:
# array(['Customer Type', 'Type of Travel', 'Class',
#        'Inflight wifi service', 'Online boarding',
#        'Inflight entertainment', 'On-board service', 'Checkin service',
#        'Inflight service', 'Arrival Delay in Minutes'], dtype=object)

# %%
X_train
# Out:
#         Gender  Customer Type  Type of Travel  Class  Age  Flight Distance  \
# 27515        0              0               0      0   59           1726.0
# 22056        0              0               0      0   26            571.0
# 53332        1              1               0      1   20            972.0
# 47247        1              0               1      1   32            563.0
# 88195        1              0               0      0   40           1536.0
# ...        ...            ...             ...    ...  ...              ...
# 42106        0              0               0      0   45            936.0
# 25835        0              0               1      1   17           1660.0
# 3264         0              0               0      1   54            365.0
# 33167        0              0               1      1   57           1173.0
# 100836       0              0               1      1   53            101.0
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 27515                       5                                  1
# 22056                       1                                  1
# 53332                       2                                  2
# 47247                       3                                  4
# 88195                       5                                  5
# ...                       ...                                ...
# 42106                       4                                  4
# 25835                       1                                  4
# 3264                        4                                  2
# 33167                       4                                  5
# 100836                      0                                  5
#
#         Ease of Online booking  Gate location  Food and drink  \
# 27515                        5              5               5
# 22056                        1              1               5
# 53332                        2              4               4
# 47247                        2              1               5
# 88195                        5              5               2
# ...                        ...            ...             ...
# 42106                        5              4               5
# 25835                        1              4               3
# 3264                         2              2               4
# 33167                        4              4               5
# 100836                       0              4               2
#
#         Online boarding  Seat comfort  Inflight entertainment  \
# 27515                 4             4                       4
# 22056                 5             5                       5
# 53332                 2             4                       4
# 47247                 2             5                       5
# 88195                 5             4                       5
# ...                 ...           ...                     ...
# 42106                 5             4                       4
# 25835                 1             4                       3
# 3264                  3             4                       4
# 33167                 5             5                       3
# 100836                4             4                       3
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 27515                  4                 5                 4                3
# 22056                  2                 4                 4                5
# 53332                  4                 5                 4                3
# 47247                  5                 2                 5                4
# 88195                  5                 5                 5                5
# ...                  ...               ...               ...              ...
# 42106                  4                 4                 4                4
# 25835                  4                 3                 5                4
# 3264                   4                 4                 4                1
# 33167                  3                 4                 3                3
# 100836                 3                 0                 3                4
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 27515                  4            4                           9
# 22056                  1            5                          30
# 53332                  4            4                           0
# 47247                  5            5                           9
# 88195                  5            5                          30
# ...                  ...          ...                         ...
# 42106                  4            5                           0
# 25835                  5            3                           2
# 3264                   4            2                          24
# 33167                  3            3                           0
# 100836                 3            4                           0
#
#         Arrival Delay in Minutes
# 27515                        0.0
# 22056                       32.5
# 53332                        0.0
# 47247                       14.0
# 88195                       32.5
# ...                          ...
# 42106                        0.0
# 25835                        6.0
# 3264                        15.0
# 33167                        0.0
# 100836                       0.0
#
# [83123 rows x 22 columns]

# %%
X_train.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Age',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
X_train = X_train.loc[:,['Customer Type', 'Type of Travel', 'Class',
       'Inflight wifi service', 'Online boarding',
       'Inflight entertainment', 'On-board service', 'Checkin service',
       'Inflight service', 'Arrival Delay in Minutes']]
X_train
# Out:
#         Customer Type  Type of Travel  Class  Inflight wifi service  \
# 27515               0               0      0                      5
# 22056               0               0      0                      1
# 53332               1               0      1                      2
# 47247               0               1      1                      3
# 88195               0               0      0                      5
# ...               ...             ...    ...                    ...
# 42106               0               0      0                      4
# 25835               0               1      1                      1
# 3264                0               0      1                      4
# 33167               0               1      1                      4
# 100836              0               1      1                      0
#
#         Online boarding  Inflight entertainment  On-board service  \
# 27515                 4                       4                 4
# 22056                 5                       5                 2
# 53332                 2                       4                 4
# 47247                 2                       5                 5
# 88195                 5                       5                 5
# ...                 ...                     ...               ...
# 42106                 5                       4                 4
# 25835                 1                       3                 4
# 3264                  3                       4                 4
# 33167                 5                       3                 3
# 100836                4                       3                 3
#
#         Checkin service  Inflight service  Arrival Delay in Minutes
# 27515                 3                 4                       0.0
# 22056                 5                 1                      32.5
# 53332                 3                 4                       0.0
# 47247                 4                 5                      14.0
# 88195                 5                 5                      32.5
# ...                 ...               ...                       ...
# 42106                 4                 4                       0.0
# 25835                 4                 5                       6.0
# 3264                  1                 4                      15.0
# 33167                 3                 3                       0.0
# 100836                4                 3                       0.0
#
# [83123 rows x 10 columns]

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
output = logreg.fit(X_train, y_train)

# %%
output.intercept_  # beto
# Out:
# array([5.55931831])

# %%
output.coef_  # Beta 1 --
# Out:
# array([[ 1.90896366,  2.89840336,  0.55862988, -0.2554593 , -0.61485554,
#         -0.32240979, -0.31698086, -0.36752277, -0.19645283,  0.0234675 ]])

# %%
train=pd.concat([X_train,y_train],axis=1)
train.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 27515              0               0      0                      5
# 22056              0               0      0                      1
# 53332              1               0      1                      2
# 47247              0               1      1                      3
# 88195              0               0      0                      5
#
#        Online boarding  Inflight entertainment  On-board service  \
# 27515                4                       4                 4
# 22056                5                       5                 2
# 53332                2                       4                 4
# 47247                2                       5                 5
# 88195                5                       5                 5
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 27515                3                 4                       0.0
# 22056                5                 1                      32.5
# 53332                3                 4                       0.0
# 47247                4                 5                      14.0
# 88195                5                 5                      32.5
#
#        satisfaction
# 27515             0
# 22056             0
# 53332             1
# 47247             1
# 88195             0

# %%
train['satisfaction'].value_counts()
# Out:
# 1    46950
# 0    36173
# Name: satisfaction, dtype: int64

# %%
train['Probability']= output.predict_proba(X_train)[:,1]
train
# Out:
#         Customer Type  Type of Travel  Class  Inflight wifi service  \
# 27515               0               0      0                      5
# 22056               0               0      0                      1
# 53332               1               0      1                      2
# 47247               0               1      1                      3
# 88195               0               0      0                      5
# ...               ...             ...    ...                    ...
# 42106               0               0      0                      4
# 25835               0               1      1                      1
# 3264                0               0      1                      4
# 33167               0               1      1                      4
# 100836              0               1      1                      0
#
#         Online boarding  Inflight entertainment  On-board service  \
# 27515                 4                       4                 4
# 22056                 5                       5                 2
# 53332                 2                       4                 4
# 47247                 2                       5                 5
# 88195                 5                       5                 5
# ...                 ...                     ...               ...
# 42106                 5                       4                 4
# 25835                 1                       3                 4
# 3264                  3                       4                 4
# 33167                 5                       3                 3
# 100836                4                       3                 3
#
#         Checkin service  Inflight service  Arrival Delay in Minutes  \
# 27515                 3                 4                       0.0
# 22056                 5                 1                      32.5
# 53332                 3                 4                       0.0
# 47247                 4                 5                      14.0
# 88195                 5                 5                      32.5
# ...                 ...               ...                       ...
# 42106                 4                 4                       0.0
# 25835                 4                 5                       6.0
# 3264                  1                 4                      15.0
# 33167                 3                 3                       0.0
# 100836                4                 3                       0.0
#
#         satisfaction  Probability
# 27515              0     0.067651
# 22056              0     0.216225
# 53332              1     0.862989
# 47247              1     0.845469
# 88195              0     0.017185
# ...              ...          ...
# 42106              0     0.033887
# 25835              1     0.973386
# 3264               1     0.473191
# 33167              1     0.787536
# 100836             0     0.929518
#
# [83123 rows x 12 columns]

# %%
train['Predicted']=np.where(train['Probability'] >= 0.5,1,0) 
train.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 27515              0               0      0                      5
# 22056              0               0      0                      1
# 53332              1               0      1                      2
# 47247              0               1      1                      3
# 88195              0               0      0                      5
#
#        Online boarding  Inflight entertainment  On-board service  \
# 27515                4                       4                 4
# 22056                5                       5                 2
# 53332                2                       4                 4
# 47247                2                       5                 5
# 88195                5                       5                 5
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 27515                3                 4                       0.0
# 22056                5                 1                      32.5
# 53332                3                 4                       0.0
# 47247                4                 5                      14.0
# 88195                5                 5                      32.5
#
#        satisfaction  Probability  Predicted
# 27515             0     0.067651          0
# 22056             0     0.216225          0
# 53332             1     0.862989          1
# 47247             1     0.845469          1
# 88195             0     0.017185          0

# %%
train['Predicted'].value_counts()
# Out:
# 1    48087
# 0    35036
# Name: Predicted, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(train['Predicted'], train['satisfaction'])
matrix
# Out:
# array([[30162,  4874],
#        [ 6011, 42076]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(train['satisfaction'],train['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85     36173
#            1       0.87      0.90      0.89     46950
#
#     accuracy                           0.87     83123
#    macro avg       0.87      0.87      0.87     83123
# weighted avg       0.87      0.87      0.87     83123

# %%
X_test = X_test.loc[:,['Customer Type', 'Type of Travel', 'Class',
       'Inflight wifi service', 'Online boarding',
       'Inflight entertainment', 'On-board service', 'Checkin service',
       'Inflight service', 'Arrival Delay in Minutes']]
X_test
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
# ...              ...             ...    ...                    ...
# 27450              0               0      0                      4
# 82070              0               1      1                      4
# 95274              0               0      2                      1
# 57529              0               0      0                      1
# 54725              0               0      0                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
# ...                ...                     ...               ...
# 27450                4                       4                 4
# 82070                0                       2                 4
# 95274                1                       1                 2
# 57529                4                       4                 4
# 54725                5                       5                 5
#
#        Checkin service  Inflight service  Arrival Delay in Minutes
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
# ...                ...               ...                       ...
# 27450                3                 4                      24.0
# 82070                4                 2                       0.0
# 95274                4                 2                       4.0
# 57529                3                 4                       0.0
# 54725                3                 5                       0.0
#
# [20781 rows x 10 columns]

# %%
test = pd.concat([X_test,y_test],axis=1)
test.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
#
#        satisfaction
# 81903             0
# 73167             0
# 11289             1
# 77137             1
# 64305             1

# %%
test['Probability']=output.predict_proba(X_test)[:,1]
test.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
#
#        satisfaction  Probability
# 81903             0     0.029126
# 73167             0     0.398172
# 11289             1     0.986572
# 77137             1     0.981278
# 64305             1     0.959747

# %%
test['Predicted']=np.where(test['Probability'] >= 0.5,1,0) 
test.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
#
#        satisfaction  Probability  Predicted
# 81903             0     0.029126          0
# 73167             0     0.398172          0
# 11289             1     0.986572          1
# 77137             1     0.981278          1
# 64305             1     0.959747          1

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(test['Predicted'],test['satisfaction'])
print(matrix)
# Out:
# [[ 7409  1161]
#  [ 1443 10768]]

# %%
from sklearn.metrics import classification_report
print(classification_report(test['satisfaction'],test['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      8852
#            1       0.88      0.90      0.89     11929
#
#     accuracy                           0.87     20781
#    macro avg       0.87      0.87      0.87     20781
# weighted avg       0.87      0.87      0.87     20781

# %% [markdown]
# ### optimal threshold by using Youden’s statistic

# %%
from sklearn.metrics import roc_curve
import numpy as np

# Assuming model is your trained classifier and y_test is the true labels
y_prob = output.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
J = tpr - fpr
optimal_idx = np.argmax(J)
optimal_threshold = thresholds[optimal_idx]
print(f"Optimal threshold: {optimal_threshold}")
# Out:
# Optimal threshold: 0.503366500384616

# %%
from sklearn.metrics import precision_score, recall_score

# %%
thresholds = [0.1,0.2,0.3, 0.4 ,0.45, 0.49,0.50,0.55,0.6, 0.7, 0.9]
for t in thresholds:
    y_pred = (train.Probability >= t).astype(int)
    precision = precision_score(y_train, y_pred)
    recall = recall_score(y_train, y_pred)
    print(f"Threshold: {t}, Precision: {precision:.2f}, Recall: {recall:.2f}")
# Out:
# Threshold: 0.1, Precision: 0.71, Recall: 1.00
# Threshold: 0.2, Precision: 0.78, Recall: 0.98
# Threshold: 0.3, Precision: 0.82, Recall: 0.96
# Threshold: 0.4, Precision: 0.85, Recall: 0.93
# Threshold: 0.45, Precision: 0.86, Recall: 0.92
# Threshold: 0.49, Precision: 0.87, Recall: 0.90
# Threshold: 0.5, Precision: 0.87, Recall: 0.90
# Threshold: 0.55, Precision: 0.88, Recall: 0.87
# Threshold: 0.6, Precision: 0.89, Recall: 0.85
# Threshold: 0.7, Precision: 0.91, Recall: 0.78
# Threshold: 0.9, Precision: 0.93, Recall: 0.51

# %%
from sklearn.metrics import auc

# %%
fpr, tpr, thresholds = roc_curve(y_test, test['Probability'])
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, 
         label=f'ROC curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random (AUC = 0.5)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# #### decision tree

# %%
from sklearn import tree

dt = tree.DecisionTreeClassifier()  # by default it use Gini index for split
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
train1 = pd.concat([y_train,X_train],axis=1)
train1.head()
# Out:
#        satisfaction  Customer Type  Type of Travel  Class  \
# 27515             0              0               0      0
# 22056             0              0               0      0
# 53332             1              1               0      1
# 47247             1              0               1      1
# 88195             0              0               0      0
#
#        Inflight wifi service  Online boarding  Inflight entertainment  \
# 27515                      5                4                       4
# 22056                      1                5                       5
# 53332                      2                2                       4
# 47247                      3                2                       5
# 88195                      5                5                       5
#
#        On-board service  Checkin service  Inflight service  \
# 27515                 4                3                 4
# 22056                 2                5                 1
# 53332                 4                3                 4
# 47247                 5                4                 5
# 88195                 5                5                 5
#
#        Arrival Delay in Minutes
# 27515                       0.0
# 22056                      32.5
# 53332                       0.0
# 47247                      14.0
# 88195                      32.5

# %%
train1['Predicted'] = dt.predict(X_train)  # MODEL = dt
train1.head()
# Out:
#        satisfaction  Customer Type  Type of Travel  Class  \
# 27515             0              0               0      0
# 22056             0              0               0      0
# 53332             1              1               0      1
# 47247             1              0               1      1
# 88195             0              0               0      0
#
#        Inflight wifi service  Online boarding  Inflight entertainment  \
# 27515                      5                4                       4
# 22056                      1                5                       5
# 53332                      2                2                       4
# 47247                      3                2                       5
# 88195                      5                5                       5
#
#        On-board service  Checkin service  Inflight service  \
# 27515                 4                3                 4
# 22056                 2                5                 1
# 53332                 4                3                 4
# 47247                 5                4                 5
# 88195                 5                5                 5
#
#        Arrival Delay in Minutes  Predicted
# 27515                       0.0          0
# 22056                      32.5          0
# 53332                       0.0          1
# 47247                      14.0          1
# 88195                      32.5          0

# %%
from sklearn.metrics import confusion_matrix  
matrix = confusion_matrix(train1['Predicted'],train1['satisfaction'])
print(matrix)
# Out:
# [[35159  1140]
#  [ 1014 45810]]

# %%
from sklearn.metrics import classification_report
print(classification_report(train1['satisfaction'], train1['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     36173
#            1       0.98      0.98      0.98     46950
#
#     accuracy                           0.97     83123
#    macro avg       0.97      0.97      0.97     83123
# weighted avg       0.97      0.97      0.97     83123

# %%
#Import Tree Classifier model
from sklearn import tree

dt = tree.DecisionTreeClassifier(criterion='gini', 
                                 min_samples_leaf=2, 
                                 min_samples_split=18,  
                                 max_depth=13)  
#Train the model using the training sets
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=13, min_samples_leaf=2, min_samples_split=18)

# %%
independent_variable = list(X_train.columns)
independent_variable
# Out:
# ['Customer Type',
#  'Type of Travel',
#  'Class',
#  'Inflight wifi service',
#  'Online boarding',
#  'Inflight entertainment',
#  'On-board service',
#  'Checkin service',
#  'Inflight service',
#  'Arrival Delay in Minutes']

# %%
train1['Predicted'] = dt.predict(X_train)  # MODEL = dt
train1.head()
# Out:
#        satisfaction  Customer Type  Type of Travel  Class  \
# 27515             0              0               0      0
# 22056             0              0               0      0
# 53332             1              1               0      1
# 47247             1              0               1      1
# 88195             0              0               0      0
#
#        Inflight wifi service  Online boarding  Inflight entertainment  \
# 27515                      5                4                       4
# 22056                      1                5                       5
# 53332                      2                2                       4
# 47247                      3                2                       5
# 88195                      5                5                       5
#
#        On-board service  Checkin service  Inflight service  \
# 27515                 4                3                 4
# 22056                 2                5                 1
# 53332                 4                3                 4
# 47247                 5                4                 5
# 88195                 5                5                 5
#
#        Arrival Delay in Minutes  Predicted
# 27515                       0.0          0
# 22056                      32.5          0
# 53332                       0.0          1
# 47247                      14.0          1
# 88195                      32.5          0

# %%
from sklearn.metrics import confusion_matrix  
matrix = confusion_matrix(train1['Predicted'],train1['satisfaction'])
print(matrix)
# Out:
# [[33766  1564]
#  [ 2407 45386]]

# %%
from sklearn.metrics import classification_report
print(classification_report(train1['satisfaction'], train1['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94     36173
#            1       0.95      0.97      0.96     46950
#
#     accuracy                           0.95     83123
#    macro avg       0.95      0.95      0.95     83123
# weighted avg       0.95      0.95      0.95     83123

# %%
test1=pd.concat([X_test,y_test],axis=1)
test1.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
#
#        satisfaction
# 81903             0
# 73167             0
# 11289             1
# 77137             1
# 64305             1

# %%
test1['Predicted'] = dt.predict(X_test)
test1.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
#
#        satisfaction  Predicted
# 81903             0          0
# 73167             0          0
# 11289             1          1
# 77137             1          1
# 64305             1          1

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(test1['Predicted'],test1['satisfaction'])
print(confusion_matrix)
# Out:
# [[ 8154   426]
#  [  698 11503]]

# %%
from sklearn.metrics import classification_report
print(classification_report(test1['satisfaction'], test1['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      8852
#            1       0.94      0.96      0.95     11929
#
#     accuracy                           0.95     20781
#    macro avg       0.95      0.94      0.94     20781
# weighted avg       0.95      0.95      0.95     20781

# %% [markdown]
# ### cross validation

# %%
from sklearn.model_selection import KFold, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {
    'max_depth': [3, 4, 5, 7, 10, 13, 16],
    'min_samples_split': [2, 5, 10, 13, 18],
    'min_samples_leaf': [ 2, 4, 6, 9],
    'criterion': ['gini', 'entropy']
}

# %%
# Grid Search with Cross-Validation
grid_search = GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid=param_grid,
    cv=10,                    # 10-fold CV
    scoring='accuracy',
    n_jobs=-1,              
    verbose=1
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 280 candidates, totalling 2800 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=42),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 7, 10, 13, 16],
#                          'min_samples_leaf': [2, 4, 6, 9],
#                          'min_samples_split': [2, 5, 10, 13, 18]},
#              scoring='accuracy', verbose=1)

# %%
print("\n=== Best Parameters ===")
print(grid_search.best_params_)
print(f"Best Cross-Validation Score: {grid_search.best_score_:.4f}")

# Best model
best_model = grid_search.best_estimator_
# Out:
# === Best Parameters ===
# {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 18}
# Best Cross-Validation Score: 0.9445

# %% [markdown]
# ### random forest

# %%
from sklearn.ensemble import RandomForestClassifier


Model = RandomForestClassifier(n_estimators=100, 
                               max_depth=15,  
                               min_samples_split=2,
                               min_samples_leaf=2,
                               max_features="log2")  

Model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=15, max_features='log2', min_samples_leaf=2)

# %%
X_train
# Out:
#         Customer Type  Type of Travel  Class  Inflight wifi service  \
# 27515               0               0      0                      5
# 22056               0               0      0                      1
# 53332               1               0      1                      2
# 47247               0               1      1                      3
# 88195               0               0      0                      5
# ...               ...             ...    ...                    ...
# 42106               0               0      0                      4
# 25835               0               1      1                      1
# 3264                0               0      1                      4
# 33167               0               1      1                      4
# 100836              0               1      1                      0
#
#         Online boarding  Inflight entertainment  On-board service  \
# 27515                 4                       4                 4
# 22056                 5                       5                 2
# 53332                 2                       4                 4
# 47247                 2                       5                 5
# 88195                 5                       5                 5
# ...                 ...                     ...               ...
# 42106                 5                       4                 4
# 25835                 1                       3                 4
# 3264                  3                       4                 4
# 33167                 5                       3                 3
# 100836                4                       3                 3
#
#         Checkin service  Inflight service  Arrival Delay in Minutes
# 27515                 3                 4                       0.0
# 22056                 5                 1                      32.5
# 53332                 3                 4                       0.0
# 47247                 4                 5                      14.0
# 88195                 5                 5                      32.5
# ...                 ...               ...                       ...
# 42106                 4                 4                       0.0
# 25835                 4                 5                       6.0
# 3264                  1                 4                      15.0
# 33167                 3                 3                       0.0
# 100836                4                 3                       0.0
#
# [83123 rows x 10 columns]

# %%
train2=pd.concat([X_train,y_train],axis=1)
train2.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 27515              0               0      0                      5
# 22056              0               0      0                      1
# 53332              1               0      1                      2
# 47247              0               1      1                      3
# 88195              0               0      0                      5
#
#        Online boarding  Inflight entertainment  On-board service  \
# 27515                4                       4                 4
# 22056                5                       5                 2
# 53332                2                       4                 4
# 47247                2                       5                 5
# 88195                5                       5                 5
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 27515                3                 4                       0.0
# 22056                5                 1                      32.5
# 53332                3                 4                       0.0
# 47247                4                 5                      14.0
# 88195                5                 5                      32.5
#
#        satisfaction
# 27515             0
# 22056             0
# 53332             1
# 47247             1
# 88195             0

# %%
train2['Predicted']=Model.predict(X_train)
train2.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 27515              0               0      0                      5
# 22056              0               0      0                      1
# 53332              1               0      1                      2
# 47247              0               1      1                      3
# 88195              0               0      0                      5
#
#        Online boarding  Inflight entertainment  On-board service  \
# 27515                4                       4                 4
# 22056                5                       5                 2
# 53332                2                       4                 4
# 47247                2                       5                 5
# 88195                5                       5                 5
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 27515                3                 4                       0.0
# 22056                5                 1                      32.5
# 53332                3                 4                       0.0
# 47247                4                 5                      14.0
# 88195                5                 5                      32.5
#
#        satisfaction  Predicted
# 27515             0          0
# 22056             0          0
# 53332             1          1
# 47247             1          1
# 88195             0          0

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(train2['satisfaction'], train2['Predicted'])
print(confusion_matrix)
# Out:
# [[33793  2380]
#  [ 1210 45740]]

# %%
from sklearn.metrics import classification_report
print(classification_report(train2['satisfaction'], train2['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     36173
#            1       0.95      0.97      0.96     46950
#
#     accuracy                           0.96     83123
#    macro avg       0.96      0.95      0.96     83123
# weighted avg       0.96      0.96      0.96     83123

# %%
test2 = pd.concat([X_test,y_test],axis=1)
test2.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
#
#        satisfaction
# 81903             0
# 73167             0
# 11289             1
# 77137             1
# 64305             1

# %%
test2['Predicted']=Model.predict(X_test)
test2.head()
# Out:
#        Customer Type  Type of Travel  Class  Inflight wifi service  \
# 81903              0               0      0                      4
# 73167              0               0      0                      3
# 11289              0               1      1                      3
# 77137              1               0      1                      1
# 64305              1               0      1                      2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 81903                5                       4                 4
# 73167                4                       2                 2
# 11289                1                       2                 2
# 77137                1                       4                 3
# 64305                2                       1                 3
#
#        Checkin service  Inflight service  Arrival Delay in Minutes  \
# 81903                5                 4                       9.0
# 73167                5                 2                      32.5
# 11289                4                 3                       0.0
# 77137                1                 3                       0.0
# 64305                3                 4                       2.0
#
#        satisfaction  Predicted
# 81903             0          0
# 73167             0          0
# 11289             1          1
# 77137             1          1
# 64305             1          1

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(test2['Predicted'],test2['satisfaction'])
print(confusion_matrix)
# Out:
# [[ 8172   358]
#  [  680 11571]]

# %%
from sklearn.metrics import classification_report
print(classification_report(test2['satisfaction'], test2['Predicted']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      8852
#            1       0.94      0.97      0.96     11929
#
#     accuracy                           0.95     20781
#    macro avg       0.95      0.95      0.95     20781
# weighted avg       0.95      0.95      0.95     20781

# %% [markdown]
# ### cross validation

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [4, 5, 10, 15],
    'min_samples_split': [2, 5, 10, 13, 18],
    'min_samples_leaf': [1, 2, 4, 6, 9],
    'max_features': ['sqrt', 'log2']
}

# %%
# Randomized Search
random_search = RandomizedSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_distributions=param_grid,
    n_iter=50,                    # Number of random combinations to try
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    random_state=42,
    verbose=2
)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'max_depth': [4, 5, 10, 15],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 9],
#                                         'min_samples_split': [2, 5, 10, 13, 18],
#                                         'n_estimators': [50, 100]},
#                    random_state=42, scoring='accuracy', verbose=2)

# %%
print(random_search.best_params_)
# Out:
# {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 15}

# %%
print(f"\nBest Cross-Validation Accuracy: {random_search.best_score_:.4f}")
# Out:
# Best Cross-Validation Accuracy: 0.9484

# %%
best_rf = random_search.best_estimator_

print("\nBest Model:")
print(best_rf)
# Out:
# Best Model:
# RandomForestClassifier(max_depth=15, max_features='log2', min_samples_leaf=2,
#                        random_state=42)
